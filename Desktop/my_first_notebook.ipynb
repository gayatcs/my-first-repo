# %% [markdown]
# Hardware provides the physical platform.
#
# Example: CPU, RAM, disk
#
# Software (like the operating system and compilers) acts as an interface that manages hardware and allows programs written in programming languages to run.
#
# Example: Python, C
